# %%
#pip install pandas dask scikit-learn numpy

# %%
#BO
import os  
import pandas as pd
import dask.dataframe as dd
from dask import delayed
from dask.distributed import Client
from sklearn.model_selection import train_test_split
from sklearn.neural_network import MLPRegressor
from sklearn.metrics import r2_score, mean_squared_error, mean_absolute_error
from sklearn.preprocessing import StandardScaler, MinMaxScaler, OneHotEncoder
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
import numpy as np
import gc

# --- FUNCIONES DE CARGA Y PREPROCESADO ---

def inicialize_dask():
    client = Client(memory_limit='8GB', processes=False)
    print(client)

def cargar_datos():
    inicialize_dask()
    data_path = '../data'
    files = os.listdir(data_path)
    
    selected_files = []
    for file in files:
        if file.endswith('.csv'):
            parts = file.split('_')
            if len(parts) < 3:
                continue
            year = parts[0]
            #if year not in ['2024', '2023', '2022']:
            #   continue
            if year not in ['2024','2023']:
                continue
            month = parts[1]
            #if year == '2024' and month not in ['05']:
            #   continue
            if year == '2023' and month not in ['0','01','02','03','05',' 06','07','08','09','10','11','12']:
               continue
            if year == '2024' and month not in ['0','01','02','03','05','06','07','08','09','10','11','12']:
               continue
            #if year == '2023' and month not in ['01', '11']:
            #    continue
            #if year == '2022' and month not in ['06']:
            #    continue
            selected_files.append(os.path.join(data_path, file))
    
    @delayed
    def process_file(file_path):
        try:
            df = pd.read_csv(file_path, low_memory=True, dtype=str, 
             usecols=['station_id', 'last_reported', 'num_bikes_available',
             'num_docks_available', 'num_bikes_available_types.mechanical', 'num_bikes_available_types.ebike', 
             'is_installed', 'is_renting', 'is_returning', 'is_charging_station'],
            skiprows=lambda i: i > 0 and i % 3 != 0)
            df['last_reported'] = pd.to_datetime(df['last_reported'], unit='s', errors='coerce')
            df['year'] = df['last_reported'].dt.year
            df['month'] = df['last_reported'].dt.month
            df['day'] = df['last_reported'].dt.day
            df['hour'] = df['last_reported'].dt.hour

            cols_to_drop = [col for col in ['traffic', 'V1'] if col in df.columns]
            if cols_to_drop:
                df.drop(columns=cols_to_drop, inplace=True)

            numeric_cols = ['num_bikes_available', 'num_docks_available', 
                            'num_bikes_available_types.mechanical', 'num_bikes_available_types.ebike']
            for col in numeric_cols:
                if col in df.columns:
                    df[col] = df[col].astype(float)
            
            df = df.dropna(how='any')
            return df
        except Exception as e:
            print(f"Error processing {file_path}: {e}")
            return pd.DataFrame()

    delayed_dfs = [process_file(file_path) for file_path in selected_files]
    
    if not delayed_dfs:
        return None

    ddf = dd.from_delayed(delayed_dfs)
    df_meta = pd.read_csv('../Informacio_Estacions_Bicing_2025.csv',
                          usecols=['station_id', 'lat', 'lon', 'capacity','altitude'],
                          low_memory=False)
    ddf['station_id'] = ddf['station_id'].astype('Int64')
    df_meta['station_id'] = df_meta['station_id'].astype('Int64')

    for col in ['is_installed', 'is_renting', 'is_returning']:
        if col in ddf.columns:
            ddf[col] = ddf[col].astype(str).replace({'nan': '0', '<NA>': '0'}).astype(int)
    
    if 'is_charging_station' in ddf.columns:
        ddf['is_charging_station'] = ddf['is_charging_station'].astype(str).map({'TRUE': 1, 'FALSE': 0}).fillna(0).astype(int)
    
    ddf = ddf.dropna(how='any')
    ddf = ddf.merge(df_meta, on='station_id', how='inner')
    ddf['sum_capacity'] = ddf['num_bikes_available'] + ddf['num_docks_available']
    df_final = ddf.compute()

    median_capacity = df_final.groupby('station_id')['sum_capacity'].median()
    df_final['capacity'] = df_final['capacity'].fillna(df_final['station_id'].map(median_capacity))
    df_final['num_docks_available'] = df_final['num_docks_available'].clip(lower=0, upper=df_final['capacity'])
    df_final['target'] = df_final['num_docks_available'] / df_final['capacity']
    df_final['altitude'] = df_final['altitude'].fillna(df_final['altitude'].median())
    aggregated_df = df_final.groupby(['station_id', 'year', 'month', 'day', 'hour']).agg(
        num_bikes_available=('num_bikes_available', 'mean'),
        num_docks_available=('num_docks_available', 'mean'),
        num_mechanical=('num_bikes_available_types.mechanical', 'median'),
        num_ebike=('num_bikes_available_types.ebike', 'median'),
        is_renting=('is_renting', 'mean'),
        is_returning=('is_returning', 'mean'),
        target=('target', 'mean'),
        lat=('lat', 'first'),
        lon=('lon', 'first'),
        altitude=('altitude','first'),
        capacity=('capacity', 'first')
    ).reset_index()

    id_df = pd.read_csv('../data/metadata_sample_submission_2025.csv')
    station_list = pd.unique(id_df['station_id'])
    aggregated_df = aggregated_df[aggregated_df['station_id'].isin(station_list)]
    
    return aggregated_df

def crear_campos_optimized(df):
    df = df.sort_values(by=['station_id', 'year', 'month', 'day', 'hour']).reset_index(drop=True)

    for lag in range(1, 5):
        df[f'ctx-{lag}'] = df.groupby('station_id')['target'].shift(lag)

    mask = df.groupby('station_id').cumcount() >= 4
    df = df[mask]
    df = df.iloc[::5].reset_index(drop=True)

    return df

def day_categorization_bcn(df):
    holiday_set = set([ "2020-01-01", "2020-01-06", "2020-04-10", "2020-04-13", "2020-05-01", "2020-06-24", 
                        "2020-09-11", "2020-09-24", "2020-10-12", "2020-11-01", "2020-12-06", "2020-12-08", 
                        "2020-12-25", "2020-12-26", "2021-01-01", "2021-01-06", "2021-04-02", "2021-04-05", 
                        "2021-05-01", "2021-06-24", "2021-09-11", "2021-09-24", "2021-10-12", "2021-11-01", 
                        "2021-12-06", "2021-12-08", "2021-12-25", "2021-12-26", "2022-01-01", "2022-01-06", 
                        "2022-04-15", "2022-04-18", "2022-05-01", "2022-06-24", "2022-09-11", "2022-09-24", 
                        "2022-10-12", "2022-11-01", "2022-12-06", "2022-12-08", "2022-12-25", "2022-12-26", 
                        "2023-01-01", "2023-01-06", "2023-04-07", "2023-04-10", "2023-05-01", "2023-06-24", 
                        "2023-09-11", "2023-09-24", "2023-10-12", "2023-11-01", "2023-12-06", "2023-12-08", 
                        "2023-12-25", "2023-12-26", "2024-01-01", "2024-01-06", "2024-03-29", "2024-04-01", 
                        "2024-05-01", "2024-06-24", "2024-09-11", "2024-09-24", "2024-10-12", "2024-11-01", 
                        "2024-12-06", "2024-12-08", "2024-12-25", "2024-12-26", "2025-01-01", "2025-01-06", 
                        "2025-04-18", "2025-04-21", "2025-05-01", "2025-06-24", "2025-09-11", "2025-09-24", 
                        "2025-10-12", "2025-11-01", "2025-12-06", "2025-12-08", "2025-12-25", "2025-12-26"])
    
    df['date'] = pd.to_datetime(df[['year', 'month', 'day']])

    df['day_type'] = 0  # Default: workday
    df.loc[df['date'].dt.weekday >= 5, 'day_type'] = 1  # Weekend
    df.loc[df['date'].astype(str).isin(holiday_set), 'day_type'] = 2  # Holiday

    return df.drop(columns=['date'])

# %%
# --- PREPARACIÓN Y PREDICCIÓN ---

# Cargar y preparar los datos una vez
df_merge = cargar_datos()
df_merge = crear_campos_optimized(df_merge)
df_merge_final = day_categorization_bcn(df_merge)

X = df_merge_final[['station_id', 'month', 'day', 'hour', 'ctx-1', 'ctx-2', 'ctx-3', 'ctx-4', 'lat', 'lon', 'altitude','day_type']]
y = df_merge_final['target']

def neural_network_model(X, y, test_size=0.2):
    # Filtrar datos de validación (junio a diciembre)
    df_validation = X[(X['month'] >= 6) & (X['month'] <= 12)]
    y_validation = y.loc[df_validation.index]
    
    # Separar los datos de entrenamiento (eliminando los de validación)
    #df_train = X[~X.index.isin(df_validation.index)] no ho trec de moment
    df_train = X[X.index.isin(df_validation.index)] 
    y_train = y.loc[df_train.index]

    # Especificación de las columnas de entrada
    percent_features = ['ctx-1', 'ctx-2', 'ctx-3', 'ctx-4']
    bounded_features = ['month', 'day', 'hour']
    continuous_features = ['lat', 'lon','altitude']
    categorical_features = ['station_id', 'day_type']

    # Asegurar que las columnas necesarias están en X_train
    missing_cols = [col for col in percent_features + bounded_features + continuous_features + categorical_features if col not in df_train.columns]
    if missing_cols:
        raise ValueError(f"Missing columns in X: {missing_cols}")

    # Definir las matrices X_train_data y X_validation_data como DataFrames
    X_train_data = df_train[percent_features + bounded_features + continuous_features + categorical_features]
    X_validation_data = df_validation[percent_features + bounded_features + continuous_features + categorical_features]

    # Escalado de las etiquetas (target)
    y_train_data = np.array(y_train).reshape(-1, 1)
    y_validation_data = np.array(y_validation).reshape(-1, 1)

    preprocessor = ColumnTransformer(
        transformers=[('percent', MinMaxScaler(), percent_features),
                      ('bounded', MinMaxScaler(), bounded_features),
                      ('continuous', StandardScaler(), continuous_features),
                      ('cat', OneHotEncoder(handle_unknown='ignore', sparse_output=False), categorical_features)]
    )

    # Escalar las etiquetas (target)
    y_scaler = MinMaxScaler()
    y_train_scaled = y_scaler.fit_transform(y_train_data)
    y_validation_scaled = y_scaler.transform(y_validation_data)

    # Definir el modelo
    model = MLPRegressor(
        hidden_layer_sizes=(128, 64),
        activation='relu',
        solver='adam',
        alpha=0.001,
        random_state=42,
        max_iter=1000,
        early_stopping=True,
        validation_fraction=0.1,
        batch_size=128,
        n_iter_no_change=10,
        verbose=1
    )

    # Crear el pipeline con preprocesamiento y modelo
    pipeline = Pipeline([('preprocess', preprocessor), ('regressor', model)])
    
    # Ajustar el modelo
    pipeline.fit(X_train_data, y_train_scaled.ravel())

    # Realizar predicciones en el conjunto de validación
    y_pred_scaled = pipeline.predict(X_validation_data)
    y_pred = y_scaler.inverse_transform(y_pred_scaled.reshape(-1, 1)).flatten()

    # Evaluar el modelo
    r2 = r2_score(y_validation_data, y_pred)
    mse = mean_squared_error(y_validation_data, y_pred)
    mae = mean_absolute_error(y_validation_data, y_pred)

    return r2, mse, mae, pipeline, X_validation_data, y_validation_data

# Resultados del modelo
r2_nn, mse_nn, mae_nn, nn_model, _, _ = neural_network_model(X, y, 0.3)

# Verificar valores antes de construir el DataFrame
print(f"R² NN: {r2_nn}, MSE NN: {mse_nn}, MAE NN: {mae_nn}")

metrics_df = pd.DataFrame({
    'Métrica': ['R²', 'MSE', 'MAE'],
    'Neural Network': [r2_nn, mse_nn, mae_nn]
})

print(metrics_df)
# Out:
# c:\Users\Pere\Anacondadef\Lib\site-packages\distributed\node.py:182: UserWarning: Port 8787 is already in use.
# Perhaps you already have a cluster running?
# Hosting the HTTP server on port 62815 instead
#   warnings.warn(
# <Client: 'inproc://192.168.1.109/14616/27' processes=1 threads=16, memory=7.45 GiB>
# C:\Users\Pere\AppData\Local\Temp\ipykernel_14616\687264477.py:59: FutureWarning: The behavior of 'to_datetime' with 'unit' when parsing strings is deprecated. In a future version, strings will be parsed as datetime strings, matching the behavior without a 'unit'. To retain the old behavior, explicitly cast ints or floats to numeric type before calling to_datetime.
#   df['last_reported'] = pd.to_datetime(df['last_reported'], unit='s', errors='coerce')
# c:\Users\Pere\Anacondadef\Lib\site-packages\dask_expr\_collection.py:4160: UserWarning:
# You did not provide metadata, so Dask is running your function on a small dataset to guess output types. It is possible that Dask will guess incorrectly.
# To provide an explicit output types or to silence this message, please provide the `meta=` keyword, as described in the map or apply function that you are using.
#   Before: .apply(func)
#   After:  .apply(func, meta=('is_charging_station', 'float64'))
#
#   warnings.warn(meta_warning(meta))
# C:\Users\Pere\AppData\Local\Temp\ipykernel_14616\687264477.py:59: FutureWarning: The behavior of 'to_datetime' with 'unit' when parsing strings is deprecated. In a future version, strings will be parsed as datetime strings, matching the behavior without a 'unit'. To retain the old behavior, explicitly cast ints or floats to numeric type before calling to_datetime.
#   df['last_reported'] = pd.to_datetime(df['last_reported'], unit='s', errors='coerce')
# C:\Users\Pere\AppData\Local\Temp\ipykernel_14616\687264477.py:59: FutureWarning: The behavior of 'to_datetime' with 'unit' when parsing strings is deprecated. In a future version, strings will be parsed as datetime strings, matching the behavior without a 'unit'. To retain the old behavior, explicitly cast ints or floats to numeric type before calling to_datetime.
#   df['last_reported'] = pd.to_datetime(df['last_reported'], unit='s', errors='coerce')
# C:\Users\Pere\AppData\Local\Temp\ipykernel_14616\687264477.py:59: FutureWarning: The behavior of 'to_datetime' with 'unit' when parsing strings is deprecated. In a future version, strings will be parsed as datetime strings, matching the behavior without a 'unit'. To retain the old behavior, explicitly cast ints or floats to numeric type before calling to_datetime.
#   df['last_reported'] = pd.to_datetime(df['last_reported'], unit='s', errors='coerce')
# C:\Users\Pere\AppData\Local\Temp\ipykernel_14616\687264477.py:59: FutureWarning: The behavior of 'to_datetime' with 'unit' when parsing strings is deprecated. In a future version, strings will be parsed as datetime strings, matching the behavior without a 'unit'. To retain the old behavior, explicitly cast ints or floats to numeric type before calling to_datetime.
#   df['last_reported'] = pd.to_datetime(df['last_reported'], unit='s', errors='coerce')
# C:\Users\Pere\AppData\Local\Temp\ipykernel_14616\687264477.py:59: FutureWarning: The behavior of 'to_datetime' with 'unit' when parsing strings is deprecated. In a future version, strings will be parsed as datetime strings, matching the behavior without a 'unit'. To retain the old behavior, explicitly cast ints or floats to numeric type before calling to_datetime.
#   df['last_reported'] = pd.to_datetime(df['last_reported'], unit='s', errors='coerce')
# C:\Users\Pere\AppData\Local\Temp\ipykernel_14616\687264477.py:59: FutureWarning: The behavior of 'to_datetime' with 'unit' when parsing strings is deprecated. In a future version, strings will be parsed as datetime strings, matching the behavior without a 'unit'. To retain the old behavior, explicitly cast ints or floats to numeric type before calling to_datetime.
#   df['last_reported'] = pd.to_datetime(df['last_reported'], unit='s', errors='coerce')
# C:\Users\Pere\AppData\Local\Temp\ipykernel_14616\687264477.py:59: FutureWarning: The behavior of 'to_datetime' with 'unit' when parsing strings is deprecated. In a future version, strings will be parsed as datetime strings, matching the behavior without a 'unit'. To retain the old behavior, explicitly cast ints or floats to numeric type before calling to_datetime.
#   df['last_reported'] = pd.to_datetime(df['last_reported'], unit='s', errors='coerce')
# C:\Users\Pere\AppData\Local\Temp\ipykernel_14616\687264477.py:59: FutureWarning: The behavior of 'to_datetime' with 'unit' when parsing strings is deprecated. In a future version, strings will be parsed as datetime strings, matching the behavior without a 'unit'. To retain the old behavior, explicitly cast ints or floats to numeric type before calling to_datetime.
#   df['last_reported'] = pd.to_datetime(df['last_reported'], unit='s', errors='coerce')
# C:\Users\Pere\AppData\Local\Temp\ipykernel_14616\687264477.py:59: FutureWarning: The behavior of 'to_datetime' with 'unit' when parsing strings is deprecated. In a future version, strings will be parsed as datetime strings, matching the behavior without a 'unit'. To retain the old behavior, explicitly cast ints or floats to numeric type before calling to_datetime.
#   df['last_reported'] = pd.to_datetime(df['last_reported'], unit='s', errors='coerce')
# C:\Users\Pere\AppData\Local\Temp\ipykernel_14616\687264477.py:59: FutureWarning: The behavior of 'to_datetime' with 'unit' when parsing strings is deprecated. In a future version, strings will be parsed as datetime strings, matching the behavior without a 'unit'. To retain the old behavior, explicitly cast ints or floats to numeric type before calling to_datetime.
#   df['last_reported'] = pd.to_datetime(df['last_reported'], unit='s', errors='coerce')
# C:\Users\Pere\AppData\Local\Temp\ipykernel_14616\687264477.py:59: FutureWarning: The behavior of 'to_datetime' with 'unit' when parsing strings is deprecated. In a future version, strings will be parsed as datetime strings, matching the behavior without a 'unit'. To retain the old behavior, explicitly cast ints or floats to numeric type before calling to_datetime.
#   df['last_reported'] = pd.to_datetime(df['last_reported'], unit='s', errors='coerce')
# C:\Users\Pere\AppData\Local\Temp\ipykernel_14616\687264477.py:59: FutureWarning: The behavior of 'to_datetime' with 'unit' when parsing strings is deprecated. In a future version, strings will be parsed as datetime strings, matching the behavior without a 'unit'. To retain the old behavior, explicitly cast ints or floats to numeric type before calling to_datetime.
#   df['last_reported'] = pd.to_datetime(df['last_reported'], unit='s', errors='coerce')
# C:\Users\Pere\AppData\Local\Temp\ipykernel_14616\687264477.py:59: FutureWarning: The behavior of 'to_datetime' with 'unit' when parsing strings is deprecated. In a future version, strings will be parsed as datetime strings, matching the behavior without a 'unit'. To retain the old behavior, explicitly cast ints or floats to numeric type before calling to_datetime.
#   df['last_reported'] = pd.to_datetime(df['last_reported'], unit='s', errors='coerce')
# C:\Users\Pere\AppData\Local\Temp\ipykernel_14616\687264477.py:59: FutureWarning: The behavior of 'to_datetime' with 'unit' when parsing strings is deprecated. In a future version, strings will be parsed as datetime strings, matching the behavior without a 'unit'. To retain the old behavior, explicitly cast ints or floats to numeric type before calling to_datetime.
#   df['last_reported'] = pd.to_datetime(df['last_reported'], unit='s', errors='coerce')
# C:\Users\Pere\AppData\Local\Temp\ipykernel_14616\687264477.py:59: FutureWarning: The behavior of 'to_datetime' with 'unit' when parsing strings is deprecated. In a future version, strings will be parsed as datetime strings, matching the behavior without a 'unit'. To retain the old behavior, explicitly cast ints or floats to numeric type before calling to_datetime.
#   df['last_reported'] = pd.to_datetime(df['last_reported'], unit='s', errors='coerce')
# C:\Users\Pere\AppData\Local\Temp\ipykernel_14616\687264477.py:59: FutureWarning: The behavior of 'to_datetime' with 'unit' when parsing strings is deprecated. In a future version, strings will be parsed as datetime strings, matching the behavior without a 'unit'. To retain the old behavior, explicitly cast ints or floats to numeric type before calling to_datetime.
#   df['last_reported'] = pd.to_datetime(df['last_reported'], unit='s', errors='coerce')
# C:\Users\Pere\AppData\Local\Temp\ipykernel_14616\687264477.py:59: FutureWarning: The behavior of 'to_datetime' with 'unit' when parsing strings is deprecated. In a future version, strings will be parsed as datetime strings, matching the behavior without a 'unit'. To retain the old behavior, explicitly cast ints or floats to numeric type before calling to_datetime.
#   df['last_reported'] = pd.to_datetime(df['last_reported'], unit='s', errors='coerce')
# C:\Users\Pere\AppData\Local\Temp\ipykernel_14616\687264477.py:59: FutureWarning: The behavior of 'to_datetime' with 'unit' when parsing strings is deprecated. In a future version, strings will be parsed as datetime strings, matching the behavior without a 'unit'. To retain the old behavior, explicitly cast ints or floats to numeric type before calling to_datetime.
#   df['last_reported'] = pd.to_datetime(df['last_reported'], unit='s', errors='coerce')
# C:\Users\Pere\AppData\Local\Temp\ipykernel_14616\687264477.py:59: FutureWarning: The behavior of 'to_datetime' with 'unit' when parsing strings is deprecated. In a future version, strings will be parsed as datetime strings, matching the behavior without a 'unit'. To retain the old behavior, explicitly cast ints or floats to numeric type before calling to_datetime.
#   df['last_reported'] = pd.to_datetime(df['last_reported'], unit='s', errors='coerce')
# C:\Users\Pere\AppData\Local\Temp\ipykernel_14616\687264477.py:59: FutureWarning: The behavior of 'to_datetime' with 'unit' when parsing strings is deprecated. In a future version, strings will be parsed as datetime strings, matching the behavior without a 'unit'. To retain the old behavior, explicitly cast ints or floats to numeric type before calling to_datetime.
#   df['last_reported'] = pd.to_datetime(df['last_reported'], unit='s', errors='coerce')
# C:\Users\Pere\AppData\Local\Temp\ipykernel_14616\687264477.py:59: FutureWarning: The behavior of 'to_datetime' with 'unit' when parsing strings is deprecated. In a future version, strings will be parsed as datetime strings, matching the behavior without a 'unit'. To retain the old behavior, explicitly cast ints or floats to numeric type before calling to_datetime.
#   df['last_reported'] = pd.to_datetime(df['last_reported'], unit='s', errors='coerce')
# C:\Users\Pere\AppData\Local\Temp\ipykernel_14616\687264477.py:59: FutureWarning: The behavior of 'to_datetime' with 'unit' when parsing strings is deprecated. In a future version, strings will be parsed as datetime strings, matching the behavior without a 'unit'. To retain the old behavior, explicitly cast ints or floats to numeric type before calling to_datetime.
#   df['last_reported'] = pd.to_datetime(df['last_reported'], unit='s', errors='coerce')
# C:\Users\Pere\AppData\Local\Temp\ipykernel_14616\687264477.py:59: FutureWarning: The behavior of 'to_datetime' with 'unit' when parsing strings is deprecated. In a future version, strings will be parsed as datetime strings, matching the behavior without a 'unit'. To retain the old behavior, explicitly cast ints or floats to numeric type before calling to_datetime.
#   df['last_reported'] = pd.to_datetime(df['last_reported'], unit='s', errors='coerce')
# C:\Users\Pere\AppData\Local\Temp\ipykernel_14616\687264477.py:59: FutureWarning: The behavior of 'to_datetime' with 'unit' when parsing strings is deprecated. In a future version, strings will be parsed as datetime strings, matching the behavior without a 'unit'. To retain the old behavior, explicitly cast ints or floats to numeric type before calling to_datetime.
#   df['last_reported'] = pd.to_datetime(df['last_reported'], unit='s', errors='coerce')
# C:\Users\Pere\AppData\Local\Temp\ipykernel_14616\687264477.py:59: FutureWarning: The behavior of 'to_datetime' with 'unit' when parsing strings is deprecated. In a future version, strings will be parsed as datetime strings, matching the behavior without a 'unit'. To retain the old behavior, explicitly cast ints or floats to numeric type before calling to_datetime.
#   df['last_reported'] = pd.to_datetime(df['last_reported'], unit='s', errors='coerce')
# C:\Users\Pere\AppData\Local\Temp\ipykernel_14616\687264477.py:59: FutureWarning: The behavior of 'to_datetime' with 'unit' when parsing strings is deprecated. In a future version, strings will be parsed as datetime strings, matching the behavior without a 'unit'. To retain the old behavior, explicitly cast ints or floats to numeric type before calling to_datetime.
#   df['last_reported'] = pd.to_datetime(df['last_reported'], unit='s', errors='coerce')
# C:\Users\Pere\AppData\Local\Temp\ipykernel_14616\687264477.py:59: FutureWarning: The behavior of 'to_datetime' with 'unit' when parsing strings is deprecated. In a future version, strings will be parsed as datetime strings, matching the behavior without a 'unit'. To retain the old behavior, explicitly cast ints or floats to numeric type before calling to_datetime.
#   df['last_reported'] = pd.to_datetime(df['last_reported'], unit='s', errors='coerce')
# C:\Users\Pere\AppData\Local\Temp\ipykernel_14616\687264477.py:59: FutureWarning: The behavior of 'to_datetime' with 'unit' when parsing strings is deprecated. In a future version, strings will be parsed as datetime strings, matching the behavior without a 'unit'. To retain the old behavior, explicitly cast ints or floats to numeric type before calling to_datetime.
#   df['last_reported'] = pd.to_datetime(df['last_reported'], unit='s', errors='coerce')
# C:\Users\Pere\AppData\Local\Temp\ipykernel_14616\687264477.py:59: FutureWarning: The behavior of 'to_datetime' with 'unit' when parsing strings is deprecated. In a future version, strings will be parsed as datetime strings, matching the behavior without a 'unit'. To retain the old behavior, explicitly cast ints or floats to numeric type before calling to_datetime.
#   df['last_reported'] = pd.to_datetime(df['last_reported'], unit='s', errors='coerce')
# C:\Users\Pere\AppData\Local\Temp\ipykernel_14616\687264477.py:59: FutureWarning: The behavior of 'to_datetime' with 'unit' when parsing strings is deprecated. In a future version, strings will be parsed as datetime strings, matching the behavior without a 'unit'. To retain the old behavior, explicitly cast ints or floats to numeric type before calling to_datetime.
#   df['last_reported'] = pd.to_datetime(df['last_reported'], unit='s', errors='coerce')
# C:\Users\Pere\AppData\Local\Temp\ipykernel_14616\687264477.py:59: FutureWarning: The behavior of 'to_datetime' with 'unit' when parsing strings is deprecated. In a future version, strings will be parsed as datetime strings, matching the behavior without a 'unit'. To retain the old behavior, explicitly cast ints or floats to numeric type before calling to_datetime.
#   df['last_reported'] = pd.to_datetime(df['last_reported'], unit='s', errors='coerce')
# C:\Users\Pere\AppData\Local\Temp\ipykernel_14616\687264477.py:59: FutureWarning: The behavior of 'to_datetime' with 'unit' when parsing strings is deprecated. In a future version, strings will be parsed as datetime strings, matching the behavior without a 'unit'. To retain the old behavior, explicitly cast ints or floats to numeric type before calling to_datetime.
#   df['last_reported'] = pd.to_datetime(df['last_reported'], unit='s', errors='coerce')
# C:\Users\Pere\AppData\Local\Temp\ipykernel_14616\687264477.py:59: FutureWarning: The behavior of 'to_datetime' with 'unit' when parsing strings is deprecated. In a future version, strings will be parsed as datetime strings, matching the behavior without a 'unit'. To retain the old behavior, explicitly cast ints or floats to numeric type before calling to_datetime.
#   df['last_reported'] = pd.to_datetime(df['last_reported'], unit='s', errors='coerce')
# C:\Users\Pere\AppData\Local\Temp\ipykernel_14616\687264477.py:59: FutureWarning: The behavior of 'to_datetime' with 'unit' when parsing strings is deprecated. In a future version, strings will be parsed as datetime strings, matching the behavior without a 'unit'. To retain the old behavior, explicitly cast ints or floats to numeric type before calling to_datetime.
#   df['last_reported'] = pd.to_datetime(df['last_reported'], unit='s', errors='coerce')
# C:\Users\Pere\AppData\Local\Temp\ipykernel_14616\687264477.py:59: FutureWarning: The behavior of 'to_datetime' with 'unit' when parsing strings is deprecated. In a future version, strings will be parsed as datetime strings, matching the behavior without a 'unit'. To retain the old behavior, explicitly cast ints or floats to numeric type before calling to_datetime.
#   df['last_reported'] = pd.to_datetime(df['last_reported'], unit='s', errors='coerce')
# C:\Users\Pere\AppData\Local\Temp\ipykernel_14616\687264477.py:59: FutureWarning: The behavior of 'to_datetime' with 'unit' when parsing strings is deprecated. In a future version, strings will be parsed as datetime strings, matching the behavior without a 'unit'. To retain the old behavior, explicitly cast ints or floats to numeric type before calling to_datetime.
#   df['last_reported'] = pd.to_datetime(df['last_reported'], unit='s', errors='coerce')
# C:\Users\Pere\AppData\Local\Temp\ipykernel_14616\687264477.py:59: FutureWarning: The behavior of 'to_datetime' with 'unit' when parsing strings is deprecated. In a future version, strings will be parsed as datetime strings, matching the behavior without a 'unit'. To retain the old behavior, explicitly cast ints or floats to numeric type before calling to_datetime.
#   df['last_reported'] = pd.to_datetime(df['last_reported'], unit='s', errors='coerce')
# C:\Users\Pere\AppData\Local\Temp\ipykernel_14616\687264477.py:59: FutureWarning: The behavior of 'to_datetime' with 'unit' when parsing strings is deprecated. In a future version, strings will be parsed as datetime strings, matching the behavior without a 'unit'. To retain the old behavior, explicitly cast ints or floats to numeric type before calling to_datetime.
#   df['last_reported'] = pd.to_datetime(df['last_reported'], unit='s', errors='coerce')
# C:\Users\Pere\AppData\Local\Temp\ipykernel_14616\687264477.py:59: FutureWarning: The behavior of 'to_datetime' with 'unit' when parsing strings is deprecated. In a future version, strings will be parsed as datetime strings, matching the behavior without a 'unit'. To retain the old behavior, explicitly cast ints or floats to numeric type before calling to_datetime.
#   df['last_reported'] = pd.to_datetime(df['last_reported'], unit='s', errors='coerce')
# C:\Users\Pere\AppData\Local\Temp\ipykernel_14616\687264477.py:59: FutureWarning: The behavior of 'to_datetime' with 'unit' when parsing strings is deprecated. In a future version, strings will be parsed as datetime strings, matching the behavior without a 'unit'. To retain the old behavior, explicitly cast ints or floats to numeric type before calling to_datetime.
#   df['last_reported'] = pd.to_datetime(df['last_reported'], unit='s', errors='coerce')
# C:\Users\Pere\AppData\Local\Temp\ipykernel_14616\687264477.py:59: FutureWarning: The behavior of 'to_datetime' with 'unit' when parsing strings is deprecated. In a future version, strings will be parsed as datetime strings, matching the behavior without a 'unit'. To retain the old behavior, explicitly cast ints or floats to numeric type before calling to_datetime.
#   df['last_reported'] = pd.to_datetime(df['last_reported'], unit='s', errors='coerce')
# C:\Users\Pere\AppData\Local\Temp\ipykernel_14616\687264477.py:59: FutureWarning: The behavior of 'to_datetime' with 'unit' when parsing strings is deprecated. In a future version, strings will be parsed as datetime strings, matching the behavior without a 'unit'. To retain the old behavior, explicitly cast ints or floats to numeric type before calling to_datetime.
#   df['last_reported'] = pd.to_datetime(df['last_reported'], unit='s', errors='coerce')
# C:\Users\Pere\AppData\Local\Temp\ipykernel_14616\687264477.py:59: FutureWarning: The behavior of 'to_datetime' with 'unit' when parsing strings is deprecated. In a future version, strings will be parsed as datetime strings, matching the behavior without a 'unit'. To retain the old behavior, explicitly cast ints or floats to numeric type before calling to_datetime.
#   df['last_reported'] = pd.to_datetime(df['last_reported'], unit='s', errors='coerce')
# C:\Users\Pere\AppData\Local\Temp\ipykernel_14616\687264477.py:59: FutureWarning: The behavior of 'to_datetime' with 'unit' when parsing strings is deprecated. In a future version, strings will be parsed as datetime strings, matching the behavior without a 'unit'. To retain the old behavior, explicitly cast ints or floats to numeric type before calling to_datetime.
#   df['last_reported'] = pd.to_datetime(df['last_reported'], unit='s', errors='coerce')
# C:\Users\Pere\AppData\Local\Temp\ipykernel_14616\687264477.py:59: FutureWarning: The behavior of 'to_datetime' with 'unit' when parsing strings is deprecated. In a future version, strings will be parsed as datetime strings, matching the behavior without a 'unit'. To retain the old behavior, explicitly cast ints or floats to numeric type before calling to_datetime.
#   df['last_reported'] = pd.to_datetime(df['last_reported'], unit='s', errors='coerce')
# C:\Users\Pere\AppData\Local\Temp\ipykernel_14616\687264477.py:59: FutureWarning: The behavior of 'to_datetime' with 'unit' when parsing strings is deprecated. In a future version, strings will be parsed as datetime strings, matching the behavior without a 'unit'. To retain the old behavior, explicitly cast ints or floats to numeric type before calling to_datetime.
#   df['last_reported'] = pd.to_datetime(df['last_reported'], unit='s', errors='coerce')
# C:\Users\Pere\AppData\Local\Temp\ipykernel_14616\687264477.py:59: FutureWarning: The behavior of 'to_datetime' with 'unit' when parsing strings is deprecated. In a future version, strings will be parsed as datetime strings, matching the behavior without a 'unit'. To retain the old behavior, explicitly cast ints or floats to numeric type before calling to_datetime.
#   df['last_reported'] = pd.to_datetime(df['last_reported'], unit='s', errors='coerce')
# C:\Users\Pere\AppData\Local\Temp\ipykernel_14616\687264477.py:59: FutureWarning: The behavior of 'to_datetime' with 'unit' when parsing strings is deprecated. In a future version, strings will be parsed as datetime strings, matching the behavior without a 'unit'. To retain the old behavior, explicitly cast ints or floats to numeric type before calling to_datetime.
#   df['last_reported'] = pd.to_datetime(df['last_reported'], unit='s', errors='coerce')
# C:\Users\Pere\AppData\Local\Temp\ipykernel_14616\687264477.py:59: FutureWarning: The behavior of 'to_datetime' with 'unit' when parsing strings is deprecated. In a future version, strings will be parsed as datetime strings, matching the behavior without a 'unit'. To retain the old behavior, explicitly cast ints or floats to numeric type before calling to_datetime.
#   df['last_reported'] = pd.to_datetime(df['last_reported'], unit='s', errors='coerce')
# C:\Users\Pere\AppData\Local\Temp\ipykernel_14616\687264477.py:59: FutureWarning: The behavior of 'to_datetime' with 'unit' when parsing strings is deprecated. In a future version, strings will be parsed as datetime strings, matching the behavior without a 'unit'. To retain the old behavior, explicitly cast ints or floats to numeric type before calling to_datetime.
#   df['last_reported'] = pd.to_datetime(df['last_reported'], unit='s', errors='coerce')
# C:\Users\Pere\AppData\Local\Temp\ipykernel_14616\687264477.py:59: FutureWarning: The behavior of 'to_datetime' with 'unit' when parsing strings is deprecated. In a future version, strings will be parsed as datetime strings, matching the behavior without a 'unit'. To retain the old behavior, explicitly cast ints or floats to numeric type before calling to_datetime.
#   df['last_reported'] = pd.to_datetime(df['last_reported'], unit='s', errors='coerce')
# C:\Users\Pere\AppData\Local\Temp\ipykernel_14616\687264477.py:59: FutureWarning: The behavior of 'to_datetime' with 'unit' when parsing strings is deprecated. In a future version, strings will be parsed as datetime strings, matching the behavior without a 'unit'. To retain the old behavior, explicitly cast ints or floats to numeric type before calling to_datetime.
#   df['last_reported'] = pd.to_datetime(df['last_reported'], unit='s', errors='coerce')
# C:\Users\Pere\AppData\Local\Temp\ipykernel_14616\687264477.py:59: FutureWarning: The behavior of 'to_datetime' with 'unit' when parsing strings is deprecated. In a future version, strings will be parsed as datetime strings, matching the behavior without a 'unit'. To retain the old behavior, explicitly cast ints or floats to numeric type before calling to_datetime.
#   df['last_reported'] = pd.to_datetime(df['last_reported'], unit='s', errors='coerce')
# C:\Users\Pere\AppData\Local\Temp\ipykernel_14616\687264477.py:59: FutureWarning: The behavior of 'to_datetime' with 'unit' when parsing strings is deprecated. In a future version, strings will be parsed as datetime strings, matching the behavior without a 'unit'. To retain the old behavior, explicitly cast ints or floats to numeric type before calling to_datetime.
#   df['last_reported'] = pd.to_datetime(df['last_reported'], unit='s', errors='coerce')
# C:\Users\Pere\AppData\Local\Temp\ipykernel_14616\687264477.py:59: FutureWarning: The behavior of 'to_datetime' with 'unit' when parsing strings is deprecated. In a future version, strings will be parsed as datetime strings, matching the behavior without a 'unit'. To retain the old behavior, explicitly cast ints or floats to numeric type before calling to_datetime.
#   df['last_reported'] = pd.to_datetime(df['last_reported'], unit='s', errors='coerce')
# C:\Users\Pere\AppData\Local\Temp\ipykernel_14616\687264477.py:59: FutureWarning: The behavior of 'to_datetime' with 'unit' when parsing strings is deprecated. In a future version, strings will be parsed as datetime strings, matching the behavior without a 'unit'. To retain the old behavior, explicitly cast ints or floats to numeric type before calling to_datetime.
#   df['last_reported'] = pd.to_datetime(df['last_reported'], unit='s', errors='coerce')
# C:\Users\Pere\AppData\Local\Temp\ipykernel_14616\687264477.py:59: FutureWarning: The behavior of 'to_datetime' with 'unit' when parsing strings is deprecated. In a future version, strings will be parsed as datetime strings, matching the behavior without a 'unit'. To retain the old behavior, explicitly cast ints or floats to numeric type before calling to_datetime.
#   df['last_reported'] = pd.to_datetime(df['last_reported'], unit='s', errors='coerce')
# C:\Users\Pere\AppData\Local\Temp\ipykernel_14616\687264477.py:59: FutureWarning: The behavior of 'to_datetime' with 'unit' when parsing strings is deprecated. In a future version, strings will be parsed as datetime strings, matching the behavior without a 'unit'. To retain the old behavior, explicitly cast ints or floats to numeric type before calling to_datetime.
#   df['last_reported'] = pd.to_datetime(df['last_reported'], unit='s', errors='coerce')
# C:\Users\Pere\AppData\Local\Temp\ipykernel_14616\687264477.py:59: FutureWarning: The behavior of 'to_datetime' with 'unit' when parsing strings is deprecated. In a future version, strings will be parsed as datetime strings, matching the behavior without a 'unit'. To retain the old behavior, explicitly cast ints or floats to numeric type before calling to_datetime.
#   df['last_reported'] = pd.to_datetime(df['last_reported'], unit='s', errors='coerce')
# C:\Users\Pere\AppData\Local\Temp\ipykernel_14616\687264477.py:59: FutureWarning: The behavior of 'to_datetime' with 'unit' when parsing strings is deprecated. In a future version, strings will be parsed as datetime strings, matching the behavior without a 'unit'. To retain the old behavior, explicitly cast ints or floats to numeric type before calling to_datetime.
#   df['last_reported'] = pd.to_datetime(df['last_reported'], unit='s', errors='coerce')
# C:\Users\Pere\AppData\Local\Temp\ipykernel_14616\687264477.py:59: FutureWarning: The behavior of 'to_datetime' with 'unit' when parsing strings is deprecated. In a future version, strings will be parsed as datetime strings, matching the behavior without a 'unit'. To retain the old behavior, explicitly cast ints or floats to numeric type before calling to_datetime.
#   df['last_reported'] = pd.to_datetime(df['last_reported'], unit='s', errors='coerce')
# C:\Users\Pere\AppData\Local\Temp\ipykernel_14616\687264477.py:59: FutureWarning: The behavior of 'to_datetime' with 'unit' when parsing strings is deprecated. In a future version, strings will be parsed as datetime strings, matching the behavior without a 'unit'. To retain the old behavior, explicitly cast ints or floats to numeric type before calling to_datetime.
#   df['last_reported'] = pd.to_datetime(df['last_reported'], unit='s', errors='coerce')
# C:\Users\Pere\AppData\Local\Temp\ipykernel_14616\687264477.py:59: FutureWarning: The behavior of 'to_datetime' with 'unit' when parsing strings is deprecated. In a future version, strings will be parsed as datetime strings, matching the behavior without a 'unit'. To retain the old behavior, explicitly cast ints or floats to numeric type before calling to_datetime.
#   df['last_reported'] = pd.to_datetime(df['last_reported'], unit='s', errors='coerce')
# C:\Users\Pere\AppData\Local\Temp\ipykernel_14616\687264477.py:59: FutureWarning: The behavior of 'to_datetime' with 'unit' when parsing strings is deprecated. In a future version, strings will be parsed as datetime strings, matching the behavior without a 'unit'. To retain the old behavior, explicitly cast ints or floats to numeric type before calling to_datetime.
#   df['last_reported'] = pd.to_datetime(df['last_reported'], unit='s', errors='coerce')
# C:\Users\Pere\AppData\Local\Temp\ipykernel_14616\687264477.py:59: FutureWarning: The behavior of 'to_datetime' with 'unit' when parsing strings is deprecated. In a future version, strings will be parsed as datetime strings, matching the behavior without a 'unit'. To retain the old behavior, explicitly cast ints or floats to numeric type before calling to_datetime.
#   df['last_reported'] = pd.to_datetime(df['last_reported'], unit='s', errors='coerce')
# C:\Users\Pere\AppData\Local\Temp\ipykernel_14616\687264477.py:59: FutureWarning: The behavior of 'to_datetime' with 'unit' when parsing strings is deprecated. In a future version, strings will be parsed as datetime strings, matching the behavior without a 'unit'. To retain the old behavior, explicitly cast ints or floats to numeric type before calling to_datetime.
#   df['last_reported'] = pd.to_datetime(df['last_reported'], unit='s', errors='coerce')
# C:\Users\Pere\AppData\Local\Temp\ipykernel_14616\687264477.py:59: FutureWarning: The behavior of 'to_datetime' with 'unit' when parsing strings is deprecated. In a future version, strings will be parsed as datetime strings, matching the behavior without a 'unit'. To retain the old behavior, explicitly cast ints or floats to numeric type before calling to_datetime.
#   df['last_reported'] = pd.to_datetime(df['last_reported'], unit='s', errors='coerce')
# C:\Users\Pere\AppData\Local\Temp\ipykernel_14616\687264477.py:59: FutureWarning: The behavior of 'to_datetime' with 'unit' when parsing strings is deprecated. In a future version, strings will be parsed as datetime strings, matching the behavior without a 'unit'. To retain the old behavior, explicitly cast ints or floats to numeric type before calling to_datetime.
#   df['last_reported'] = pd.to_datetime(df['last_reported'], unit='s', errors='coerce')
# C:\Users\Pere\AppData\Local\Temp\ipykernel_14616\687264477.py:59: FutureWarning: The behavior of 'to_datetime' with 'unit' when parsing strings is deprecated. In a future version, strings will be parsed as datetime strings, matching the behavior without a 'unit'. To retain the old behavior, explicitly cast ints or floats to numeric type before calling to_datetime.
#   df['last_reported'] = pd.to_datetime(df['last_reported'], unit='s', errors='coerce')
# C:\Users\Pere\AppData\Local\Temp\ipykernel_14616\687264477.py:59: FutureWarning: The behavior of 'to_datetime' with 'unit' when parsing strings is deprecated. In a future version, strings will be parsed as datetime strings, matching the behavior without a 'unit'. To retain the old behavior, explicitly cast ints or floats to numeric type before calling to_datetime.
#   df['last_reported'] = pd.to_datetime(df['last_reported'], unit='s', errors='coerce')
# C:\Users\Pere\AppData\Local\Temp\ipykernel_14616\687264477.py:59: FutureWarning: The behavior of 'to_datetime' with 'unit' when parsing strings is deprecated. In a future version, strings will be parsed as datetime strings, matching the behavior without a 'unit'. To retain the old behavior, explicitly cast ints or floats to numeric type before calling to_datetime.
#   df['last_reported'] = pd.to_datetime(df['last_reported'], unit='s', errors='coerce')
# C:\Users\Pere\AppData\Local\Temp\ipykernel_14616\687264477.py:59: FutureWarning: The behavior of 'to_datetime' with 'unit' when parsing strings is deprecated. In a future version, strings will be parsed as datetime strings, matching the behavior without a 'unit'. To retain the old behavior, explicitly cast ints or floats to numeric type before calling to_datetime.
#   df['last_reported'] = pd.to_datetime(df['last_reported'], unit='s', errors='coerce')
# C:\Users\Pere\AppData\Local\Temp\ipykernel_14616\687264477.py:59: FutureWarning: The behavior of 'to_datetime' with 'unit' when parsing strings is deprecated. In a future version, strings will be parsed as datetime strings, matching the behavior without a 'unit'. To retain the old behavior, explicitly cast ints or floats to numeric type before calling to_datetime.
#   df['last_reported'] = pd.to_datetime(df['last_reported'], unit='s', errors='coerce')
# C:\Users\Pere\AppData\Local\Temp\ipykernel_14616\687264477.py:59: FutureWarning: The behavior of 'to_datetime' with 'unit' when parsing strings is deprecated. In a future version, strings will be parsed as datetime strings, matching the behavior without a 'unit'. To retain the old behavior, explicitly cast ints or floats to numeric type before calling to_datetime.
#   df['last_reported'] = pd.to_datetime(df['last_reported'], unit='s', errors='coerce')
# C:\Users\Pere\AppData\Local\Temp\ipykernel_14616\687264477.py:59: FutureWarning: The behavior of 'to_datetime' with 'unit' when parsing strings is deprecated. In a future version, strings will be parsed as datetime strings, matching the behavior without a 'unit'. To retain the old behavior, explicitly cast ints or floats to numeric type before calling to_datetime.
#   df['last_reported'] = pd.to_datetime(df['last_reported'], unit='s', errors='coerce')
# C:\Users\Pere\AppData\Local\Temp\ipykernel_14616\687264477.py:59: FutureWarning: The behavior of 'to_datetime' with 'unit' when parsing strings is deprecated. In a future version, strings will be parsed as datetime strings, matching the behavior without a 'unit'. To retain the old behavior, explicitly cast ints or floats to numeric type before calling to_datetime.
#   df['last_reported'] = pd.to_datetime(df['last_reported'], unit='s', errors='coerce')
# C:\Users\Pere\AppData\Local\Temp\ipykernel_14616\687264477.py:59: FutureWarning: The behavior of 'to_datetime' with 'unit' when parsing strings is deprecated. In a future version, strings will be parsed as datetime strings, matching the behavior without a 'unit'. To retain the old behavior, explicitly cast ints or floats to numeric type before calling to_datetime.
#   df['last_reported'] = pd.to_datetime(df['last_reported'], unit='s', errors='coerce')
# C:\Users\Pere\AppData\Local\Temp\ipykernel_14616\687264477.py:59: FutureWarning: The behavior of 'to_datetime' with 'unit' when parsing strings is deprecated. In a future version, strings will be parsed as datetime strings, matching the behavior without a 'unit'. To retain the old behavior, explicitly cast ints or floats to numeric type before calling to_datetime.
#   df['last_reported'] = pd.to_datetime(df['last_reported'], unit='s', errors='coerce')
# C:\Users\Pere\AppData\Local\Temp\ipykernel_14616\687264477.py:59: FutureWarning: The behavior of 'to_datetime' with 'unit' when parsing strings is deprecated. In a future version, strings will be parsed as datetime strings, matching the behavior without a 'unit'. To retain the old behavior, explicitly cast ints or floats to numeric type before calling to_datetime.
#   df['last_reported'] = pd.to_datetime(df['last_reported'], unit='s', errors='coerce')
# 2025-03-29 20:35:33,283 - distributed.utils_perf - WARNING - full garbage collections took 79% CPU time recently (threshold: 10%)
# Iteration 1, loss = 0.00787304
# Validation score: 0.838328
# Iteration 2, loss = 0.00585841
# Validation score: 0.845593
# Iteration 3, loss = 0.00554995
# Validation score: 0.848118
# Iteration 4, loss = 0.00538300
# Validation score: 0.850373
# Iteration 5, loss = 0.00527872
# Validation score: 0.853151
# Iteration 6, loss = 0.00519467
# Validation score: 0.854425
# Iteration 7, loss = 0.00514596
# Validation score: 0.855492
# Iteration 8, loss = 0.00511485
# Validation score: 0.856422
# Iteration 9, loss = 0.00507533
# Validation score: 0.857274
# Iteration 10, loss = 0.00505103
# Validation score: 0.858486
# Iteration 11, loss = 0.00503377
# Validation score: 0.856309
# Iteration 12, loss = 0.00500755
# Validation score: 0.857838
# Iteration 13, loss = 0.00498855
# Validation score: 0.855898
# Iteration 14, loss = 0.00498225
# Validation score: 0.858262
# Iteration 15, loss = 0.00496513
# Validation score: 0.859860
# Iteration 16, loss = 0.00495916
# Validation score: 0.859375
# Iteration 17, loss = 0.00494711
# Validation score: 0.858497
# Iteration 18, loss = 0.00494297
# Validation score: 0.856777
# Iteration 19, loss = 0.00493821
# Validation score: 0.860981
# Iteration 20, loss = 0.00493144
# Validation score: 0.860248
# Iteration 21, loss = 0.00491861
# Validation score: 0.859471
# Iteration 22, loss = 0.00491927
# Validation score: 0.860877
# Iteration 23, loss = 0.00490332
# Validation score: 0.861128
# Iteration 24, loss = 0.00491274
# Validation score: 0.858742
# Iteration 25, loss = 0.00490201
# Validation score: 0.861103
# Iteration 26, loss = 0.00488636
# Validation score: 0.855481
# Iteration 27, loss = 0.00488887
# Validation score: 0.857468
# Iteration 28, loss = 0.00488395
# Validation score: 0.861621
# Iteration 29, loss = 0.00488447
# Validation score: 0.857372
# Iteration 30, loss = 0.00487260
# Validation score: 0.860860
# Iteration 31, loss = 0.00486753
# Validation score: 0.861509
# Iteration 32, loss = 0.00487883
# Validation score: 0.860679
# Iteration 33, loss = 0.00486678
# Validation score: 0.861747
# Iteration 34, loss = 0.00486105
# Validation score: 0.861069
# Iteration 35, loss = 0.00485683
# Validation score: 0.857375
# Iteration 36, loss = 0.00485928
# Validation score: 0.860466
# Iteration 37, loss = 0.00486353
# Validation score: 0.861623
# Iteration 38, loss = 0.00485518
# Validation score: 0.859429
# Iteration 39, loss = 0.00484785
# Validation score: 0.860940
# Iteration 40, loss = 0.00485370
# Validation score: 0.860946
# Iteration 41, loss = 0.00484316
# Validation score: 0.856680
# Iteration 42, loss = 0.00484181
# Validation score: 0.862111
# Iteration 43, loss = 0.00483879
# Validation score: 0.860602
# Iteration 44, loss = 0.00484768
# Validation score: 0.861302
# Iteration 45, loss = 0.00484419
# Validation score: 0.860854
# Iteration 46, loss = 0.00484138
# Validation score: 0.858639
# Iteration 47, loss = 0.00483673
# Validation score: 0.861163
# Iteration 48, loss = 0.00483632
# Validation score: 0.860983
# Iteration 49, loss = 0.00483611
# Validation score: 0.861238
# Iteration 50, loss = 0.00482627
# Validation score: 0.860009
# Iteration 51, loss = 0.00483549
# Validation score: 0.861955
# Iteration 52, loss = 0.00483173
# Validation score: 0.861249
# Iteration 53, loss = 0.00483531
# Validation score: 0.859411
# Validation score did not improve more than tol=0.000100 for 10 consecutive epochs. Stopping.
# R² NN: 0.8711201009979069, MSE NN: 0.008909279399840719, MAE NN: 0.06324797649464428
#   Métrica  Neural Network
# 0      R²        0.871120
# 1     MSE        0.008909
# 2     MAE        0.063248

# %%
import pandas as pd
from sklearn.preprocessing import LabelEncoder
import gc

# --- CARGA PARCIAL DEL DATASET, INCLUYENDO 'index' ---
use_cols = ['index', 'station_id', 'month', 'day', 'hour', 'ctx-4', 'ctx-3', 'ctx-2', 'ctx-1']
df = pd.read_csv('../data/metadata_sample_submission_2025.csv', usecols=use_cols)

df['year'] = 2024  # Necesario para `day_categorization_bcn`

# --- IMPUTACIÓN DE LAT/LON ---
df_merge_final = df_merge_final[['station_id', 'lat', 'lon','altitude']].drop_duplicates()
df = df.merge(df_merge_final, on='station_id', how='left')

# --- CLASIFICACIÓN DEL DÍA ---
df = day_categorization_bcn(df)

# --- CONVERSIÓN DE CATEGÓRICAS (si hace falta) ---
if df['day_type'].dtype == 'object':
    df['day_type'] = LabelEncoder().fit_transform(df['day_type'])

# --- PREDICCIÓN POR LOTES ---
features = ['station_id', 'month', 'day', 'hour', 'ctx-4', 'ctx-3', 'ctx-2', 'ctx-1', 'lat', 'lon', 'altitude','day_type']
X_predict = df[features]

batch_size = 5000
predictions = []

for start in range(0, len(X_predict), batch_size):
    end = start + batch_size
    batch = X_predict.iloc[start:end]
    preds = nn_model.predict(batch)
    predictions.extend(preds)
    del batch
    gc.collect()

# --- CREACIÓN DEL DF FINAL PARA ENTREGABLE ---
df['percentage_docks_available'] = predictions
df_final = df[['index', 'percentage_docks_available']]
df_final.to_csv('predictions1.csv', index=False)

print("✅ Archivo 'predictions.csv' creado correctamente.")
# Out:
# 2025-03-29 20:40:01,018 - distributed.utils_perf - WARNING - full garbage collections took 86% CPU time recently (threshold: 10%)
# 2025-03-29 20:40:01,232 - distributed.utils_perf - WARNING - full garbage collections took 86% CPU time recently (threshold: 10%)
# 2025-03-29 20:40:01,464 - distributed.utils_perf - WARNING - full garbage collections took 85% CPU time recently (threshold: 10%)
# 2025-03-29 20:40:01,687 - distributed.utils_perf - WARNING - full garbage collections took 85% CPU time recently (threshold: 10%)
# 2025-03-29 20:40:01,873 - distributed.utils_perf - WARNING - full garbage collections took 85% CPU time recently (threshold: 10%)
# 2025-03-29 20:40:02,138 - distributed.utils_perf - WARNING - full garbage collections took 85% CPU time recently (threshold: 10%)
# 2025-03-29 20:40:02,332 - distributed.utils_perf - WARNING - full garbage collections took 85% CPU time recently (threshold: 10%)
# 2025-03-29 20:40:02,587 - distributed.utils_perf - WARNING - full garbage collections took 85% CPU time recently (threshold: 10%)
# 2025-03-29 20:40:02,802 - distributed.utils_perf - WARNING - full garbage collections took 85% CPU time recently (threshold: 10%)
# 2025-03-29 20:40:03,058 - distributed.utils_perf - WARNING - full garbage collections took 85% CPU time recently (threshold: 10%)
# 2025-03-29 20:40:03,329 - distributed.utils_perf - WARNING - full garbage collections took 85% CPU time recently (threshold: 10%)
# 2025-03-29 20:40:03,562 - distributed.utils_perf - WARNING - full garbage collections took 85% CPU time recently (threshold: 10%)
# 2025-03-29 20:40:03,822 - distributed.utils_perf - WARNING - full garbage collections took 85% CPU time recently (threshold: 10%)
# 2025-03-29 20:40:04,098 - distributed.utils_perf - WARNING - full garbage collections took 85% CPU time recently (threshold: 10%)
# 2025-03-29 20:40:04,359 - distributed.utils_perf - WARNING - full garbage collections took 85% CPU time recently (threshold: 10%)
# 2025-03-29 20:40:04,627 - distributed.utils_perf - WARNING - full garbage collections took 85% CPU time recently (threshold: 10%)
# 2025-03-29 20:40:04,855 - distributed.utils_perf - WARNING - full garbage collections took 85% CPU time recently (threshold: 10%)
# 2025-03-29 20:40:05,050 - distributed.utils_perf - WARNING - full garbage collections took 85% CPU time recently (threshold: 10%)
# 2025-03-29 20:40:05,323 - distributed.utils_perf - WARNING - full garbage collections took 85% CPU time recently (threshold: 10%)
# 2025-03-29 20:40:05,574 - distributed.utils_perf - WARNING - full garbage collections took 86% CPU time recently (threshold: 10%)
# 2025-03-29 20:40:05,845 - distributed.utils_perf - WARNING - full garbage collections took 86% CPU time recently (threshold: 10%)
# 2025-03-29 20:40:06,145 - distributed.utils_perf - WARNING - full garbage collections took 86% CPU time recently (threshold: 10%)
# 2025-03-29 20:40:06,388 - distributed.utils_perf - WARNING - full garbage collections took 86% CPU time recently (threshold: 10%)
# 2025-03-29 20:40:06,683 - distributed.utils_perf - WARNING - full garbage collections took 86% CPU time recently (threshold: 10%)
# 2025-03-29 20:40:06,881 - distributed.utils_perf - WARNING - full garbage collections took 86% CPU time recently (threshold: 10%)
# 2025-03-29 20:40:07,107 - distributed.utils_perf - WARNING - full garbage collections took 86% CPU time recently (threshold: 10%)
# 2025-03-29 20:40:07,336 - distributed.utils_perf - WARNING - full garbage collections took 86% CPU time recently (threshold: 10%)
# 2025-03-29 20:40:07,600 - distributed.utils_perf - WARNING - full garbage collections took 86% CPU time recently (threshold: 10%)
# 2025-03-29 20:40:07,847 - distributed.utils_perf - WARNING - full garbage collections took 86% CPU time recently (threshold: 10%)
# 2025-03-29 20:40:08,058 - distributed.utils_perf - WARNING - full garbage collections took 85% CPU time recently (threshold: 10%)
# 2025-03-29 20:40:08,287 - distributed.utils_perf - WARNING - full garbage collections took 85% CPU time recently (threshold: 10%)
# 2025-03-29 20:40:08,550 - distributed.utils_perf - WARNING - full garbage collections took 85% CPU time recently (threshold: 10%)
# 2025-03-29 20:40:08,786 - distributed.utils_perf - WARNING - full garbage collections took 86% CPU time recently (threshold: 10%)
# 2025-03-29 20:40:09,070 - distributed.utils_perf - WARNING - full garbage collections took 85% CPU time recently (threshold: 10%)
# 2025-03-29 20:40:09,296 - distributed.utils_perf - WARNING - full garbage collections took 85% CPU time recently (threshold: 10%)
# 2025-03-29 20:40:09,539 - distributed.utils_perf - WARNING - full garbage collections took 85% CPU time recently (threshold: 10%)
# 2025-03-29 20:40:09,793 - distributed.utils_perf - WARNING - full garbage collections took 85% CPU time recently (threshold: 10%)
# 2025-03-29 20:40:10,010 - distributed.utils_perf - WARNING - full garbage collections took 86% CPU time recently (threshold: 10%)
# 2025-03-29 20:40:10,245 - distributed.utils_perf - WARNING - full garbage collections took 85% CPU time recently (threshold: 10%)
# 2025-03-29 20:40:10,471 - distributed.utils_perf - WARNING - full garbage collections took 85% CPU time recently (threshold: 10%)
# 2025-03-29 20:40:10,710 - distributed.utils_perf - WARNING - full garbage collections took 85% CPU time recently (threshold: 10%)
# 2025-03-29 20:40:10,940 - distributed.utils_perf - WARNING - full garbage collections took 86% CPU time recently (threshold: 10%)
# 2025-03-29 20:40:11,198 - distributed.utils_perf - WARNING - full garbage collections took 86% CPU time recently (threshold: 10%)
# 2025-03-29 20:40:11,430 - distributed.utils_perf - WARNING - full garbage collections took 86% CPU time recently (threshold: 10%)
# 2025-03-29 20:40:11,646 - distributed.utils_perf - WARNING - full garbage collections took 86% CPU time recently (threshold: 10%)
# 2025-03-29 20:40:11,836 - distributed.utils_perf - WARNING - full garbage collections took 86% CPU time recently (threshold: 10%)
# 2025-03-29 20:40:12,091 - distributed.utils_perf - WARNING - full garbage collections took 86% CPU time recently (threshold: 10%)
# 2025-03-29 20:40:12,299 - distributed.utils_perf - WARNING - full garbage collections took 85% CPU time recently (threshold: 10%)
# 2025-03-29 20:40:12,526 - distributed.utils_perf - WARNING - full garbage collections took 85% CPU time recently (threshold: 10%)
# 2025-03-29 20:40:12,758 - distributed.utils_perf - WARNING - full garbage collections took 85% CPU time recently (threshold: 10%)
# 2025-03-29 20:40:12,968 - distributed.utils_perf - WARNING - full garbage collections took 85% CPU time recently (threshold: 10%)
# ✅ Archivo 'predictions.csv' creado correctamente.
